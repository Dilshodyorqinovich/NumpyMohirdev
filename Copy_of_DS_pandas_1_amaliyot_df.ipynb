# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilshodyorqinovich/NumpyMohirdev/blob/main/Copy_of_DS_pandas_1_amaliyot_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# # **AMALIYOT**
# ## 3.1 Series va Index

# %% [markdown]
# ### **1-mashq**. `Pandas` kutubxonasini `pd`, `numpy` kutubxonasini `np` deb chaqirib oling

# %%
# Javobni shuyerga yozing
import pandas as pd
import numpy as np

# %%
#@title To'g'ri javob
import pandas as pd
import numpy as np

# %% [markdown]
# ### **2-mashq.** O'zbekiston Respublikasi viloyatlaridan iborat bir o'lchamli Series obyektini yarating

# %%
# Javobni shu yerga yozing
regs = pd.Series([
    "Andijon",
    "Bukhara",
    "Farg'ona",
    "Jizzax",
    "Xorazm",
    "Namangan",
    "Navoiy",
    "Qashqadaryo",
    "Surxandaryo",
    "Sirdaryo",
    "Samarqand",
    "Toshkent",
    "Qoraqalpog'iston Respublikasi"

])
print(regs)
# Out:
# 0                           Andijon
# 1                           Bukhara
# 2                          Farg'ona
# 3                            Jizzax
# 4                            Xorazm
# 5                          Namangan
# 6                            Navoiy
# 7                       Qashqadaryo
# 8                       Surxandaryo
# 9                          Sirdaryo
# 10                        Samarqand
# 11                         Toshkent
# 12    Qoraqalpog'iston Respublikasi
# dtype: object

# %%
#@title **To'g'ri javob**
obj = pd.Series(
    [
        "Andijon",
        "Buxoro",
        "Farg'ona",
        "Jizzax",
        "Xorazm",
        "Namangan",
        "Navoiy",
        "Qashqadaryo",
        "Qoraqalpog'iston Respublikasi",
        "Samarqand",
        "Sirdaryo",
        "Surxondaryo",
        "Toshkent",
    ]
)
print(obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4126461049.py in <cell line: 0>()
#       1 #@title **To'g'ri javob**
# ----> 2 obj = pd.Series(
#       3     [
#       4         "Andijon",
#       5         "Buxoro",
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### **3-mashq.** Yuqorida yaratilgan Series obyektining barcha qiymaltarini chiqaring

# %%
# Javobni shuyerga yozing
arr = np.array(regs)
arr
regs.values
# Out:
# array(['Andijon', 'Bukhara', "Farg'ona", 'Jizzax', 'Xorazm', 'Namangan',
#        'Navoiy', 'Qashqadaryo', 'Surxandaryo', 'Sirdaryo', 'Samarqand',
#        'Toshkent', "Qoraqalpog'iston Respublikasi"], dtype=object)

# %%
# @title **To'g'ri javob**
obj.values
# Out:
# array(['Andijon', 'Buxoro', "Farg'ona", 'Jizzax', 'Xorazm', 'Namangan',
#        'Navoiy', 'Qashqadaryo', "Qoraqalpog'iston Respublikasi",
#        'Samarqand', 'Sirdaryo', 'Surxondaryo', 'Toshkent'], dtype=object)

# %% [markdown]
# ### **4-mashq.** Yuqoridagi Series obyektining eng birinchi qiymatini chiqaring

# %%
# Javobni shuyerga yozing
regs[0]
# Out:
# 'Andijon'

# %%
# @title **To'g'ri javob**
obj[0]
# Out:
# 'Andijon'

# %% [markdown]
# ### **5-mashq.** Yuqoridagi Series obyektining eng oxirgi qiymatini chiqaring

# %%
# Javobni shuyerga yozing
regs[12]
# Out:
# "Qoraqalpog'iston Respublikasi"

# %%
# @title **To'g'ri javob**
obj[12]
# Out:
# 'Toshkent'

# %% [markdown]
# ### **6-mashq.** Yuqoridagi Series obyekti uzunligini chiqaring

# %%
# Javobni shuyerga yozing
print(len(regs))
regs.size
# Out:
# 13
# 13

# %%
# @title **To'g'ri javob**
obj.size
# Out:
# 13

# %% [markdown]
# ### **7-mashq.** Yuqoridagi Series obyektining o'rtasidan 3 ta qiymat chiqaring

# %%
# Javobni shuyerga yozing
regs[[4,6,8]]
# Out:
# 4         Xorazm
# 6         Navoiy
# 8    Surxandaryo
# dtype: object

# %%
# @title **To'g'ri javob**

obj[[5, 6, 7]]
# Out:
# 5       Namangan
# 6         Navoiy
# 7    Qashqadaryo
# dtype: object

# %% [markdown]
# ### **8-mashq.** Quyidagi Series obyektini yarating.
# **Ahamiyat bering. `Series` obyekti indeksi sifatida viloyatlar nomi ishlatilgan**

# %%
# @title
ind = obj.values
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
obj2 = pd.Series(aholi, index=ind)
print(obj2)
# Out:
# 1899000    1899000
# 1384700    1384700
# 2597000    2597000
# 910500      910500
# 1200000    1200000
# 1862000    1862000
# 767500      767500
# 2029000    2029000
# 1200000    1200000
# 2322000    2322000
# 648100      648100
# 1676000    1676000
# 4450000    4450000
# dtype: int64

# %%
# Javobni shuyerga yozing
ind = regs.values
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
    ]
obj = pd.Series(aholi, index=ind)
print(obj)
# Out:
# Andijon                          1899000
# Bukhara                          1384700
# Farg'ona                         2597000
# Jizzax                            910500
# Xorazm                           1200000
# Namangan                         1862000
# Navoiy                            767500
# Qashqadaryo                      2029000
# Surxandaryo                      1200000
# Sirdaryo                         2322000
# Samarqand                         648100
# Toshkent                         1676000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %% [markdown]
# ### **9-mashq.** Yuqoridagi `Series` obyektidan Jizzax, Buxoro va Namangan viloyatlarining aholisini chiqaring

# %%
# Javobni shuyerga yozing
obj[["Jizzax", "Bukhara", "Namangan"]]
# Out:
# Jizzax       910500
# Bukhara     1384700
# Namangan    1862000
# dtype: int64

# %%
# @title **To'g'ri javob**
obj2[["Jizzax", "Buxoro", "Namangan"]]
# Out:
# Jizzax       910500
# Buxoro      1384700
# Namangan    1862000
# dtype: int64

# %% [markdown]
# ### **10-mashq.** Yuqoridagi `Series` obyektidan aholi soni 1 milliondan kam va ko'p bo'lgan viloyatlarni alohida chiqaring

# %%
# Javobni shuyerga yozing
obj2 = obj[obj>1000000]
print(obj2)
# Out:
# Andijon                          1899000
# Bukhara                          1384700
# Farg'ona                         2597000
# Xorazm                           1200000
# Namangan                         1862000
# Qashqadaryo                      2029000
# Surxandaryo                      1200000
# Sirdaryo                         2322000
# Toshkent                         1676000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %%
# @title **To'g'ri javob**
print("Aholisi 1 milliondan ko'p viloyatlar")
print(obj2[obj2 > 1_000_000])
# Pythonda katta sonlarni yozishda 0 orasini _ bilan ajratish mumkin
# Out:
# Aholisi 1 milliondan ko'p viloyatlar
# Andijon                          1899000
# Bukhara                          1384700
# Farg'ona                         2597000
# Xorazm                           1200000
# Namangan                         1862000
# Qashqadaryo                      2029000
# Surxandaryo                      1200000
# Sirdaryo                         2322000
# Toshkent                         1676000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %%
# @title
print("Aholisi 1 milliondan kam viloyatlar")
print(obj2[obj2 < 1_000_000])
# Out:
# Aholisi 1 milliondan kam viloyatlar
# Series([], dtype: int64)

# %% [markdown]
# ### **11-mashq.** Aholisi 1 milliondan ko'p davlatlar orasida Navoiy viloyati bor/yo'qligini tekshiring

# %%
# Javobni shuyerga yozing
"Navoiy" in obj2[obj2 > 1_000_000]
# Out:
# False

# %%
# @title **To'g'ri javob**
"Navoiy" in obj2[obj2 > 1_000_000]
# Out:
# False

# %% [markdown]
# ### **12-mashq.** Quyidagi lug'atda viloyatlar va ularning maydonlari berilgan. Lug'atdan yangi `Series` obyektini yarating va unga "Hududlar hajmi" deb nom bering

# %%
dict = {
    "Andijon": 4200,
    "Buxoro": 39400,
    "Farg'ona": 6800,
    "Jizzax": 20500,
    "Xorazm": 6300,
    "Namangan": 7900,
    "Navoiy": 110800,
    "Qashqadaryo": 28400,
    "Qoraqalpog'iston Respublikasi": 160000,
    "Samarqand": 16400,
    "Sirdaryo": 5100,
    "Surxondaryo": 20800,
    "Toshkent": 15300,
}

# %%
# Javobni shuyerga yozing
obj3 = pd.Series(dict)
obj3.name = "Hudular hajmi"
print(obj3)
# Out:
# Andijon                            4200
# Buxoro                            39400
# Farg'ona                           6800
# Jizzax                            20500
# Xorazm                             6300
# Namangan                           7900
# Navoiy                           110800
# Qashqadaryo                       28400
# Qoraqalpog'iston Respublikasi    160000
# Samarqand                         16400
# Sirdaryo                           5100
# Surxondaryo                       20800
# Toshkent                          15300
# Name: Hudular hajmi, dtype: int64

# %%
#@title To'g'ri javob
obj3 = pd.Series(dict)
obj3.name = "Hudular hajmi"
print(obj3)
# Out:
# 0    <class 'dict'>
# Name: Hudular hajmi, dtype: object

# %% [markdown]
# ### **13-mashq.** Yuqoridagi `Series` obyektidan hududi eng katta va eng kichik elementlarni chiqaring

# %%
# Javobni shuyerga yozing
print(f"Eng katta hudud: {obj3.idxmax()}")
print(f"Eng kichik hudud: {obj3.idxmin()}")
# Out:
# Eng katta hudud: Qoraqalpog'iston Respublikasi
# Eng kichik hudud: Andijon

# %%
#@title To'g'ri javob
print(f"Eng katta hudud: {obj3.idxmax()}")
print(f"Eng kichik hudud: {obj3.idxmin()}")
# Out:
# Eng katta hudud: Qoraqalpog'iston Respublikasi
# Eng kichik hudud: Andijon

# %% [markdown]
# ### **14-mashq.** Yuqoridagi eng katta va eng kichik hududlar aholisi sonini chiqaring

# %%
# Javobni shuyerga yozing
print(f"{obj3.idxmax()} aholisi {obj2[obj3.idxmax()]}")
print(f"{obj3.idxmin()} aholisi {obj2[obj3.idxmin()]}")
# Out:
# Qoraqalpog'iston Respublikasi aholisi 4450000
# Andijon aholisi 1899000

# %%
#@title To'g'ri javob
print(f"{obj3.idxmax()} aholisi {obj2[obj3.idxmax()]}")
print(f"{obj3.idxmin()} aholisi {obj2[obj3.idxmin()]}")
# Out:
# Qoraqalpog'iston Respublikasi aholisi 1200000
# Andijon aholisi 1899000

# %% [markdown]
# ### **15-mashq**. Yuqoridagi hudulardan O'zbekiston Respublikasi hududini hisoblang

# %%
# Javobni shuyerga yozing
sum(obj3)
# Out:
# 441900

# %%
#@title To'g'ri javob
sum(obj3)
# Out:
# 441900

# %% [markdown]
# ### **16-mashq.** Aholisi eng ko'p va eng kam hududlarning hajmini va aholi sonini chiqaring

# %%
# Javobni shuyerga yozing
print(f"{obj3.idxmax()} aholisi {obj2[obj3.idxmax()]}, hududi {obj3[obj3.idxmax()]}kv.km ")
print(f"{obj3.idxmin()} aholisi {obj2[obj3.idxmin()]}, hududi {obj3[obj3.idxmin()]}kv.km ")
# Out:
# Qoraqalpog'iston Respublikasi aholisi 4450000, hududi 160000
# Andijon aholisi 1899000, hududi 4200

# %%
#@title To'g'ri javob
print(f"{obj2.idxmax()} hududi {obj3[obj2.idxmax()]}kv.km, aholisi {obj2[obj2.idxmax()]}")
print(f"{obj2.idxmin()} hududi {obj3[obj2.idxmin()]}kv.km, aholisi {obj2[obj2.idxmin()]}")
# Out:
# Toshkent hududi 15300kv.km, aholisi 4450000
# Sirdaryo hududi 5100kv.km, aholisi 648100

# %% [markdown]
# ### **17-mashq.** Yuqoridagi ikki obyektdan foydalangan holda O'zbekiston respublikasi tarkibidagi hududlarni avval aholi soni bo'yicha, keyin esa hajmi bo'yicha tartiblab chiqaring

# %%
# Javobni shuyerga yozing
print("Hududlar hajmi bo'yicha tartiblash")
obj3.sort_values()
print("Hududlar hajmi bo'yicha tartiblash")
obj2.sort_values()
# Out:
# Hududlar hajmi bo'yicha tartiblash
# Hududlar hajmi bo'yicha tartiblash
# Xorazm                           1200000
# Surxandaryo                      1200000
# Bukhara                          1384700
# Toshkent                         1676000
# Namangan                         1862000
# Andijon                          1899000
# Qashqadaryo                      2029000
# Sirdaryo                         2322000
# Farg'ona                         2597000
# Qoraqalpog'iston Respublikasi    4450000
# dtype: int64

# %%
#@title To'g'ri javob
print("Hududlar hajmi bo'yicha tartiblash")
obj3.sort_values()
# Out:
# Hududlar hajmi bo'yicha tartiblash
# Andijon                            4200
# Sirdaryo                           5100
# Xorazm                             6300
# Farg'ona                           6800
# Namangan                           7900
# Toshkent                          15300
# Samarqand                         16400
# Jizzax                            20500
# Surxondaryo                       20800
# Qashqadaryo                       28400
# Buxoro                            39400
# Navoiy                           110800
# Qoraqalpog'iston Respublikasi    160000
# Name: Hudular hajmi, dtype: int64

# %%
#@title To'g'ri javob
print("Aholi soni bo'yicha tartiblash")
obj2.sort_values()
# Out:
# Aholi soni bo'yicha tartiblash
# Sirdaryo                          648100
# Navoiy                            767500
# Jizzax                            910500
# Xorazm                           1200000
# Qoraqalpog'iston Respublikasi    1200000
# Buxoro                           1384700
# Surxondaryo                      1676000
# Namangan                         1862000
# Andijon                          1899000
# Qashqadaryo                      2029000
# Samarqand                        2322000
# Farg'ona                         2597000
# Toshkent                         4450000
# dtype: int64
